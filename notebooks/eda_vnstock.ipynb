# %%
from vnstock3 import Vnstock

# %%
vnstock = Vnstock()
vnstock

# %%
stock1 = vnstock.stock(symbol='HSG', source='VCI')
stock1
# Out:
# 2024-10-24 08:54:20,830 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS

# %%
all_symbols_list = stock1.listing.all_symbols()['ticker'].to_list()

# %%
df_symbols_by_exchange = stock1.listing.symbols_by_exchange()

# %%
df_symbols_by_industry_icb = stock1.listing.symbols_by_industries()

# %%
industries_icb = stock1.listing.industries_icb()

# %%
vn30 = stock1.listing.symbols_by_group('VN30')
vn30
# Out:
# 0     ACB
# 1     BCM
# 2     BID
# 3     BVH
# 4     CTG
# 5     FPT
# 6     GAS
# 7     GVR
# 8     HDB
# 9     HPG
# 10    MBB
# 11    MSN
# 12    MWG
# 13    PLX
# 14    POW
# 15    SAB
# 16    SHB
# 17    SSB
# 18    SSI
# 19    STB
# 20    TCB
# 21    TPB
# 22    VCB
# 23    VHM
# 24    VIB
# 25    VIC
# 26    VJC
# 27    VNM
# 28    VPB
# 29    VRE
# Name: symbol, dtype: object

# %%
hose = stock1.listing.symbols_by_group('VNMidCap')
hose
# Out:
# 0     AAA
# 1     ANV
# 2     ASM
# 3     BCG
# 4     BMP
#      ...
# 65    VHC
# 66    VIX
# 67    VND
# 68    VPI
# 69    VSH
# Name: symbol, Length: 70, dtype: object

# %%
stock1.listing.symbols_by_group()
# Out:
# 0     ACB
# 1     BCM
# 2     BID
# 3     BVH
# 4     CTG
# 5     FPT
# 6     GAS
# 7     GVR
# 8     HDB
# 9     HPG
# 10    MBB
# 11    MSN
# 12    MWG
# 13    PLX
# 14    POW
# 15    SAB
# 16    SHB
# 17    SSB
# 18    SSI
# 19    STB
# 20    TCB
# 21    TPB
# 22    VCB
# 23    VHM
# 24    VIB
# 25    VIC
# 26    VJC
# 27    VNM
# 28    VPB
# 29    VRE
# Name: symbol, dtype: object
